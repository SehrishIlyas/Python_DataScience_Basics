# %% [markdown]
# # 24- Pandas use in Python (Day-11)

# %% [markdown]
# Import Libaries first. If you have not installed already Install using
# + pip install numpy
# + pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
# Object creation
s = pd.Series([1,3,5,7,8,9])
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    8
# 5    9
# dtype: int64

# %%
dates = pd.date_range("20220101", periods=11)
dates
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10', '2022-01-11'],
#               dtype='datetime64[ns]', freq='D')

# %%
df= pd.DataFrame(np.random.randn(11,4), index= dates, columns= list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2022-01-01  0.308907  0.532189  1.158862  2.393970
# 2022-01-02  0.662188 -0.694541 -0.501254 -0.230474
# 2022-01-03 -0.427857 -0.632534 -1.013305  0.917657
# 2022-01-04 -0.761247  0.707542 -1.490261 -0.409392
# 2022-01-05  0.265538  0.698510  1.098850  0.485188
# 2022-01-06  0.378288 -0.514674 -0.281610 -1.726529
# 2022-01-07 -0.676186  1.822315  0.380398 -0.120214
# 2022-01-08  0.537790 -0.261984  0.681968  0.602632
# 2022-01-09 -0.745759 -0.051176  1.824554 -0.056884
# 2022-01-10  0.481771 -0.303413  0.773160 -0.679678
# 2022-01-11  0.338046  0.487376  0.340689 -0.871097

# %%
df2= pd.DataFrame(
    {
        "A":1.0,
        "B":pd.Timestamp("20200101"),
        "C":pd.Series(1, index=list(range(4)), dtype="float32"),
        "D":np.array([3]*4, dtype="int32"),
        "E":pd.Categorical(["test","train","test","train"]),
        "F": "foo"
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2020-01-01  1.0  3   test  foo
# 1  1.0 2020-01-01  1.0  3  train  foo
# 2  1.0 2020-01-01  1.0  3   test  foo
# 3  1.0 2020-01-01  1.0  3  train  foo

# %%
df2= pd.DataFrame(
    {
        "A":1.0,
        "B":pd.Timestamp("20200101"),
        "C":pd.Series(1, index=list(range(4)), dtype="float32"),
        "D":np.array([3]*4, dtype="int32"),
        "E":pd.Categorical(["girl","woman","girl","woman"]),
        "F": "female"
    }
)
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.head()
df2.tail()
# Out:
#      A          B    C  D      E       F
# 0  1.0 2020-01-01  1.0  3   girl  female
# 1  1.0 2020-01-01  1.0  3  woman  female
# 2  1.0 2020-01-01  1.0  3   girl  female
# 3  1.0 2020-01-01  1.0  3  woman  female

# %%
df2.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df2.to_numpy()
# Out:
# <bound method DataFrame.to_numpy of      A          B    C  D      E       F
# 0  1.0 2020-01-01  1.0  3   girl  female
# 1  1.0 2020-01-01  1.0  3  woman  female
# 2  1.0 2020-01-01  1.0  3   girl  female
# 3  1.0 2020-01-01  1.0  3  woman  female>

# %%
df2.describe()
# Out:
#          A    C    D
# count  4.0  4.0  4.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %%
df2.transpose
# Out:
# <bound method DataFrame.transpose of      A          B    C  D      E       F
# 0  1.0 2020-01-01  1.0  3   girl  female
# 1  1.0 2020-01-01  1.0  3  woman  female
# 2  1.0 2020-01-01  1.0  3   girl  female
# 3  1.0 2020-01-01  1.0  3  woman  female>

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2020-01-01 00:00:00  2020-01-01 00:00:00  2020-01-01 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                
df.at[dates[6], "A"]
# Out:
# -0.6761861307550163

# %%
df[df["A"]>0]
# Out:
#                    A         B         C         D
# 2022-01-01  0.308907  0.532189  1.158862  2.393970
# 2022-01-02  0.662188 -0.694541 -0.501254 -0.230474
# 2022-01-05  0.265538  0.698510  1.098850  0.485188
# 2022-01-06  0.378288 -0.514674 -0.281610 -1.726529
# 2022-01-08  0.537790 -0.261984  0.681968  0.602632
# 2022-01-10  0.481771 -0.303413  0.773160 -0.679678
# 2022-01-11  0.338046  0.487376  0.340689 -0.871097

# %%
dfc=df.copy()
dfc["newcolumn"]= [1,2,3,4,8,3,4,4,8,3,4]
dfc
# Out:
#                    A         B         C         D  newcolumn
# 2022-01-01  0.308907  0.532189  1.158862  2.393970          1
# 2022-01-02  0.662188 -0.694541 -0.501254 -0.230474          2
# 2022-01-03 -0.427857 -0.632534 -1.013305  0.917657          3
# 2022-01-04 -0.761247  0.707542 -1.490261 -0.409392          4
# 2022-01-05  0.265538  0.698510  1.098850  0.485188          8
# 2022-01-06  0.378288 -0.514674 -0.281610 -1.726529          3
# 2022-01-07 -0.676186  1.822315  0.380398 -0.120214          4
# 2022-01-08  0.537790 -0.261984  0.681968  0.602632          4
# 2022-01-09 -0.745759 -0.051176  1.824554 -0.056884          8
# 2022-01-10  0.481771 -0.303413  0.773160 -0.679678          3
# 2022-01-11  0.338046  0.487376  0.340689 -0.871097          4

# %%
dfc['mean'] = dfc.mean(axis=1)
dfc
# Out:
#                    A         B         C         D  newcolumn      mean
# 2022-01-01  0.308907  0.532189  1.158862  2.393970          1  1.078786
# 2022-01-02  0.662188 -0.694541 -0.501254 -0.230474          2  0.247184
# 2022-01-03 -0.427857 -0.632534 -1.013305  0.917657          3  0.368792
# 2022-01-04 -0.761247  0.707542 -1.490261 -0.409392          4  0.409328
# 2022-01-05  0.265538  0.698510  1.098850  0.485188          8  2.109617
# 2022-01-06  0.378288 -0.514674 -0.281610 -1.726529          3  0.171095
# 2022-01-07 -0.676186  1.822315  0.380398 -0.120214          4  1.081262
# 2022-01-08  0.537790 -0.261984  0.681968  0.602632          4  1.112081
# 2022-01-09 -0.745759 -0.051176  1.824554 -0.056884          8  1.794147
# 2022-01-10  0.481771 -0.303413  0.773160 -0.679678          3  0.654368
# 2022-01-11  0.338046  0.487376  0.340689 -0.871097          4  0.859003

# %%
dfc= dfc["A", "B", "C", "D","newcolumn"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('A', 'B', 'C', 'D', 'newcolumn')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
dfc= dfc.iloc[:,0:4]
dfc
# Out:
#                    A
# 2022-01-01  0.308907
# 2022-01-02  0.662188
# 2022-01-03 -0.427857
# 2022-01-04 -0.761247
# 2022-01-05  0.265538
# 2022-01-06  0.378288
# 2022-01-07 -0.676186
# 2022-01-08  0.537790
# 2022-01-09 -0.745759
# 2022-01-10  0.481771
# 2022-01-11  0.338046
