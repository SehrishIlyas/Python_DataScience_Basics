# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("FAOSTAT_data_1-12-2022.csv")
df.head()
# Out:
#   Domain Code           Domain  Area Code (FAO)         Area  Element Code  \
# 0          PP  Producer Prices                2  Afghanistan          5530
# 1          PP  Producer Prices                2  Afghanistan          5530
# 2          PP  Producer Prices                2  Afghanistan          5530
# 3          PP  Producer Prices                2  Afghanistan          5530
# 4          PP  Producer Prices                2  Afghanistan          5530
#
#                       Element  Item Code                 Item  Year Code  \
# 0  Producer Price (LCU/tonne)        515               Apples       1993
# 1  Producer Price (LCU/tonne)         44               Barley       1993
# 2  Producer Price (LCU/tonne)       1062  Eggs, hen, in shell       1993
# 3  Producer Price (LCU/tonne)        560               Grapes       1993
# 4  Producer Price (LCU/tonne)         15                Wheat       1993
#
#    Year  Months Code        Months Unit  Value Flag Flag Description
# ...

# %%
df.describe()
# Out:
#        Area Code (FAO)  Element Code     Item Code     Year Code  \
# count     25261.000000  25261.000000  25261.000000  25261.000000
# mean         84.242904   5534.253197    481.283322   2005.198171
# std          49.061263      3.983868    300.757218      8.207590
# min           2.000000   5530.000000     15.000000   1991.000000
# 25%          38.000000   5531.000000    249.000000   1998.000000
# 50%         100.000000   5532.000000    426.000000   2005.000000
# 75%         117.000000   5539.000000    667.000000   2012.000000
# max         165.000000   5539.000000   1182.000000   2020.000000
#
#                Year  Months Code         Value
# count  25261.000000      25261.0  2.526100e+04
# mean    2005.198171       7021.0  1.169082e+06
# std        8.207590          0.0  1.261779e+07
# min     1991.000000       7021.0  0.000000e+00
# 25%     1998.000000       7021.0  7.900000e+01
# 50%     2005.000000       7021.0  5.030000e+02
# 75%     2012.000000       7021.0  2.109000e+04
# ...

# %%
df.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (FAO)', 'Area', 'Element Code',
#        'Element', 'Item Code', 'Item', 'Year Code', 'Year', 'Months Code',
#        'Months', 'Unit', 'Value', 'Flag', 'Flag Description'],
#       dtype='object')

# %%
ndf = df.loc[:, ["Area","Item","Year","Value"]]
ndf.head()
# Out:
#           Area                 Item  Year  Value
# 0  Afghanistan               Apples  1993   6100
# 1  Afghanistan               Barley  1993   6300
# 2  Afghanistan  Eggs, hen, in shell  1993  18000
# 3  Afghanistan               Grapes  1993  24000
# 4  Afghanistan                Wheat  1993   3500

# %%
ndf.value_counts('Item')
# Out:
# Item
# Eggs, hen, in shell           1079
# Wheat                         1064
# Tomatoes                       962
# Cucumbers and gherkins         951
# Barley                         917
# Garlic                         848
# Carrots and turnips            834
# Apples                         819
# Sugar cane                     797
# Ginger                         792
# Eggplants (aubergines)         786
# Tobacco, unmanufactured        758
# Millet                         742
# Sweet potatoes                 719
# Groundnuts, with shell         712
# Bananas                        700
# Grapes                         632
# Spinach                        616
# Watermelons                    611
# Tea                            598
# Beans, green                   589
# Honey, natural                 582
# Wool, greasy                   575
# Beans, dry                     535
# Fruit, citrus nes              503
# Fruit, fresh nes               450
# ...

# %%
ndf.groupby(['Area']).mean()
# Out:
#                                    Year         Value
# Area
# Afghanistan                 2004.785924  8.172651e+03
# Bangladesh                  2004.393072  8.082011e+03
# Bhutan                      2007.899020  1.453031e+04
# China, Hong Kong SAR        2004.150522  3.995218e+03
# China, mainland             2005.402497  2.659617e+03
# India                       2002.867614  2.762144e+03
# Iran (Islamic Republic of)  2006.419555  8.472192e+06
# Japan                       2005.388521  2.317802e+05
# Maldives                    2011.734848  9.058119e+03
# Mongolia                    2006.528008  1.240721e+06
# Nepal                       2007.500805  2.804711e+04
# Pakistan                    2003.249164  6.259208e+03
# Republic of Korea           2002.164522  8.551028e+05
# Sri Lanka                   2004.731992  5.816717e+04

# %%
ndf.groupby(["Area","Item"]).count()
# Out:
#                                      Year  Value
# Area        Item
# Afghanistan Apples                     71     71
#             Barley                     65     65
#             Cotton lint                33     33
#             Cottonseed                 29     29
#             Eggs, hen, in shell        55     55
# ...                                   ...    ...
# Sri Lanka   Sugar cane                113    113
#             Sweet potatoes            119    119
#             Tea                       101    101
#             Tobacco, unmanufactured    62     62
#             Tomatoes                  119    119
#
# [369 rows x 2 columns]

# %%
ndf["Value"].max()
# Out:
# 731551000

# %%
sns.catplot(x='Year', y="Value", hue='Area', kind='bar', data=df)

# %%
sns.barplot(x = "Area", y= "Value", data = df)
plt.title("Values ka plot")
# Out:
# Text(0.5, 1.0, 'Values ka plot')

# %%
sns.lineplot(x = "Year", y= "Value", data = df)
plt.title("Phooloun ka plot")
# Out:
# Text(0.5, 1.0, 'Phooloun ka plot')

# %%
pk = df[df["Area"]=="Pakistan"]
pk
# Out:
#       Domain Code           Domain  Area Code (FAO)      Area  Element Code  \
# 19195          PP  Producer Prices              165  Pakistan          5530
# 19196          PP  Producer Prices              165  Pakistan          5530
# 19197          PP  Producer Prices              165  Pakistan          5530
# 19198          PP  Producer Prices              165  Pakistan          5530
# 19199          PP  Producer Prices              165  Pakistan          5530
# ...           ...              ...              ...       ...           ...
# 20984          PP  Producer Prices              165  Pakistan          5539
# 20985          PP  Producer Prices              165  Pakistan          5539
# 20986          PP  Producer Prices              165  Pakistan          5539
# 20987          PP  Producer Prices              165  Pakistan          5539
# 20988          PP  Producer Prices              165  Pakistan          5539
#
# ...

# %%
sns.lineplot(x = "Year", y= "Value", data = pk)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
a= pk[pk["Item"]=="Apples"]
a.head()
# Out:
#       Domain Code           Domain  Area Code (FAO)      Area  Element Code  \
# 19195          PP  Producer Prices              165  Pakistan          5530
# 19209          PP  Producer Prices              165  Pakistan          5530
# 19223          PP  Producer Prices              165  Pakistan          5530
# 19237          PP  Producer Prices              165  Pakistan          5530
# 19251          PP  Producer Prices              165  Pakistan          5530
#
#                           Element  Item Code    Item  Year Code  Year  \
# 19195  Producer Price (LCU/tonne)        515  Apples       1991  1991
# 19209  Producer Price (LCU/tonne)        515  Apples       1992  1992
# 19223  Producer Price (LCU/tonne)        515  Apples       1993  1993
# 19237  Producer Price (LCU/tonne)        515  Apples       1994  1994
# 19251  Producer Price (LCU/tonne)        515  Apples       1995  1995
#
#        Months Code        Months Unit  Value Flag Flag Description
# ...

# %%
sns.lineplot(x = "Year", y= "Value", data = a)
plt.title("Phooloun ka plot")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>
