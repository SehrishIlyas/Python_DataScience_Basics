# %% [markdown]
# # Data Visualization

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.set_theme(style='ticks', color_codes=True)
titanic= sns.load_dataset('titanic')
sns.catplot(x='sex', y="survived", hue='class', kind='bar', data=titanic)

# %% [markdown]
# ## Line Plot

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.lineplot(x = "sepal_length", y= "sepal_width", data = iris)
plt.title("Line plot")
# Out:
# Text(0.5, 1.0, 'Line plot')

# %%
sns.lineplot(x = "sepal_length", y= "sepal_width", data = iris)
plt.title("Plot")
plt.xlim(2)
plt.ylim(1)
# Out:
# (1.0, 4.00625)

# %% [markdown]
# ### Set Style
#
# The ways of styling themes are as follows:
#
# + white
# + dark
# + whitegrid
# + darkgrid
# + ticks

# %%
sns.set_style('whitegrid')
sns.lineplot(x = "sepal_length", y= "sepal_width", data = iris)
plt.title("Plot")
plt.figure(figsize=(8,6))

# %% [markdown]
# ## Bar Plot

# %%
sns.barplot(x = "species", y= "sepal_width", data = iris)
plt.title("Bar plot")
# Out:
# Text(0.5, 1.0, 'Bar plot')

# %%
sns.barplot(x = "species", y= "petal_length", data = iris)
plt.title("Bar ka plot")
# Out:
# Text(0.5, 1.0, 'Bar ka plot')

# %%
sns.barplot(x = "sex", y= "alone", hue= "who", data = titanic)
# Out:
# <Axes: xlabel='sex', ylabel='alone'>

# %%
sns.barplot(x = "sex", y= "alone", hue= "who", data = titanic, order=["female", "male"], color= 'red', ci= None, palette="pastel", saturation=0.1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22000\1897760457.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = "sex", y= "alone", hue= "who", data = titanic, order=["female", "male"], color= 'red', ci= None, palette="pastel", saturation=0.1)
# <Axes: xlabel='sex', ylabel='alone'>

# %%
import numpy
sns.barplot(x = "class", y= "fare", hue= "sex", data = titanic, palette="pastel", estimator=np.median)
# Out:
# <Axes: xlabel='class', ylabel='fare'>
